# %%
import oop
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import oop
#
# ModuleNotFoundError: No module named 'oop'

# %%
from decimal import Decimal

# %%
from decimal import Decimal

class Account:
    def __init__(self, name: str, balance: Decimal):
        self.name = name
        self.balance = balance

    def deposit(self, amount: Decimal):
        if amount <= 0:
            raise ValueError("Deposit amount must be positive")
        self.balance += amount
        return self.balance

    def __repr__(self):
        return f"Account(name={self.name}, balance={self.balance})"

    def WithDraw(self, amount: Decimal):
        if self.balance < amount:
            raise ValueError(f"You do not have sufficient balance in your account, balance : {self.balance}")
        self.balance -= amount
        return self.balance

# %%
account1 = Account("john cena", Decimal("50.00"))

# %%
account1.name
# Out:
# 'john cena'

# %%
account1.balance
# Out:
# Decimal('50.00')

# %%
account1.deposit(Decimal('25.23'))
# Out:
# Decimal('75.23')

# %%
account1.WithDraw(Decimal('35.37'))
# Out:
# Decimal('39.86')

# %%
account1.balance
# Out:
# Decimal('39.86')

# %%
class Time:
    def __init__(self, current):
        

        def ticking_clock():
            while True:
                now = datetime.now()  # get current time each iteration
                hrs = now.hour
                mins = now.minute
                secs = now.second
        
        # print time with leading zeros
                print(f'{hrs:02d}:{mins:02d}:{secs:02d}', end='\r')
                time.sleep(1)
        self.hour = hour
        self.minute = minute
        self.second = second

    # def wake_up(hour, minute, second):

# %%
while True:
    print("Press 0 to exit")
    
 
    options = ['Wake_up', 'Sleep']
    for i, name in enumerate(options):
        print(f"Press {i+1} to set {name} timer")

    choice = input("Enter your choice: ")
    
    if choice == '0':
        print("Exiting...")
        break 

 
    elif choice in ['1', '2']:
        timer_value = input(f"Set {options[int(choice)-1]} timer in (hour minutes sec): ")
        print(f"{options[int(choice)-1]} timer set to {timer_value} minutes.\n")
    
    else:
        print("Invalid choice, try again.\n")

    hrs, min, sec = timer_value.split()
    if choice == 1:
        wake_up(hrs, min, sec)
    elif choice == 2:
        pass
        # sleep(hrs, min, sec)
# Out:
# Press 0 to exit
# Press 1 to set Wake_up timer
# Press 2 to set Sleep timer
# Enter your choice:  1
# Set Wake_up timer in (hour minutes sec):  12 22 11
# Wake_up timer set to 12 22 11 minutes.
#
# Press 0 to exit
# Press 1 to set Wake_up timer
# Press 2 to set Sleep timer
# Enter your choice:  0
# Exiting...

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 9, 28, 11, 55, 32, 937387)

# %%
datetime.year()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 datetime.year()
#
# TypeError: 'getset_descriptor' object is not callable

# %%
now = datetime.now()

# %%
now.hour
# Out:
# 11

# %%
from datetime import datetime 
import time

# %%
def ticking_clock():
    now = datetime.now()

    hrs = now.hour
    min = now.minute
    sec = now.second

    while True:
        print(f'{hrs:02d}:{min:02d}:{sec:02d}',end = '\r')
        time.sleep(1)
        if sec != 0:
            sec-=1
        elif min != 0:
            min -= 1
            sec = 59
        elif hrs != 0:
            hrs -= 1
            min = 59
            sec = 59
        else:
            print ('error')

# %%
ticking_clock()
# Out:
# 17:27:57
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 ticking_clock()
#
# Cell In[9], line 10, in ticking_clock()
#       8 while True:
#       9     print(f'{hrs:02d}:{min:02d}:{sec:02d}',end = '\r')
# ---> 10     time.sleep(1)
#      11     if sec != 0:
#      12         sec-=1
#
# KeyboardInterrupt:

# %%
hi

# %%
import time
from datetime import datetime

def ticking_clock():
    while True:
        now = datetime.now()  # get current time each iteration
        hrs = now.hour
        mins = now.minute
        secs = now.second
        
        # print time with leading zeros
        print(f'{hrs:02d}:{mins:02d}:{secs:02d}', end='\r')
        time.sleep(1)

ticking_clock()
# Out:
# 18:36:05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 15
#      12         print(f'{hrs:02d}:{mins:02d}:{secs:02d}', end='\r')
#      13         time.sleep(1)
# ---> 15 ticking_clock()
#
# Cell In[11], line 13, in ticking_clock()
#      11 # print time with leading zeros
#      12 print(f'{hrs:02d}:{mins:02d}:{secs:02d}', end='\r')
# ---> 13 time.sleep(1)
#
# KeyboardInterrupt:

# %%
print("hello")
# Out:
# hello

# %%
import time
print("Hi")
while True:

    print("(O O)", end = '\r')
    time.sleep(1)
    print("(~ ~)", end = '\r')
    time.sleep(1)
    print("(O O)", end = '\r')
# Out:
# Hi
# (O O)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[97], line 6
#       3 while True:
#       5     print("(O O)", end = '\r')
# ----> 6     time.sleep(1)
#       7     print("(~ ~)", end = '\r')
#       8     time.sleep(1)
#
# KeyboardInterrupt:

# %%
import time 

for i in range(10):
    print("0",end = " ", end = '\r')
    print(" 0",end = " ", end = '\r')
    print("  0",end = " ", end = '\r')
    print("   0",end = " ", end = '\r')
    print("    0",end = " ", end = '\r')
    print("     0",end = " ", end = '\r')
    print("      0",end = " ", end = '\r')
    print("       0",end = " ", end = '\r')
    print("        0",end = " ", end = '\r')
    print("         0",end = " ", end = '\r')
    print("          0",end = " ", end = '\r')
    print("           0",end = " ", end = '\r')
    print("            0",end = " ", end = '\r')
    print("             0",end = " ", end = '\r')
    print("______________________________________________",end = '\r')
# Out:
# ______________________________________________

# %%
import time

for _ in range(10):  # loop a few cycles
    for i in range(20):  # move "0" across 20 spaces
        print(" " * i + "0", end="\r")  # overwrite same line
        time.sleep(0.05)
# Out:
# 0                  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 6
#       4 for i in range(20):  # move "0" across 20 spaces
#       5     print(" " * i + "0", end="\r")  # overwrite same line
# ----> 6     time.sleep(0.05)
#
# KeyboardInterrupt:

# %%
import time

for i in range(3):  
    for j in range(20):  
        time.sleep(0.08)
        print(" " * j + "C", end="\r") 
        time.sleep(0.08)
        print(" " * j + "c", end="\r")
# Out:
#                    c

# %%
import time, sys

width = 30
for i in range(3):
    for j in range(20):
        for pac in ["C", "c"]:
            sys.stdout.write(" " * j + pac + " " * (width - j) + "\r")
            sys.stdout.flush()
            time.sleep(0.08)
# Out:
#                    c

# %%
class Time:

    def __init__(self, hour=0, minute=0, second=0):
        self.hour = hour
        self.minute = minute
        self.second = second

    @property
    def hour(self):
        return self._hour
    
    @hour.setter
    def hour(self, hour):
        if not (0 <= hour < 24):
            raise ValueError(f"Hour ({hour}) must be 0–23")
        self._hour = hour

    @property
    def minute(self):
        return self._minute

    @minute.setter
    def minute(self, minute):
        if not (0 <= minute < 60):
            raise ValueError(f"Minute ({minute}) must be 0–59")
        self._minute = minute

    @property
    def second(self):
        return self._second

    @second.setter
    def second(self, second):
        if not (0 <= second < 60):
            raise ValueError(f"Second ({second}) must be 0–59")
        self._second = second

    def set_time(self, hour=0, minute=0, second=0):
        self.hour = hour
        self.minute = minute
        self.second = second

    def __repr__(self):
        return f"Time(hour={self.hour}, minute={self.minute}, second={self.second})"

    def __str__(self):
        return (
            ("12" if self.hour in (0, 12) else str(self.hour % 12))
            + f":{self.minute:0>2}:{self.second:0>2}"
            + ("AM" if self.hour < 12 else " PM")
        )

# %%
t = Time()

# %%
t
# Out:
# Time(hour=0, minute=0, second=0)

# %%
t.time = (12, 30, 45)

# %%
t
# Out:
# Time(hour=0, minute=0, second=0)

# %%
t.time
# Out:
# (12, 30, 45)

# %%
t
# Out:
# Time(hour=0, minute=0, second=0)

# %%
t.time
# Out:
# (12, 30, 45)

# %%
a.b = 5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 a.b = 5
#
# NameError: name 'a' is not defined

# %%
print(t)
# Out:
# 12:00:00AM

# %%
class Checking:

    def check(self):
        self.public = 10         # normal public attribute
        self._notpublic = 10     # convention: "protected" (not strictly private)
        self.__private = 15      # name-mangled "private" attribute

# %%
a = Checking()

# %% [raw]
# a = Checking()  # runs the method and creates the attributes

# %%
a.check()

# %%
print(a.public)
# Out:
# 10

# %%
print(a._notpublic)
# Out:
# 10

# %%
print(a._Checking__private)
# Out:
# 15

# %% [markdown]
# I am practicing it

# %%
class PrivateClass:

    def __init__(self):
        self.public_data = 10
        self.__private_data = 12

# %%
class PrivateClass:

    def __init__(self):
        self.public_data = 10
        self.__private_data = 15

# %%
my_object = PrivateClass()

# %%
my_object.public_data
# Out:
# 10

# %%
my_object._Privateclass__private_data = 20

# %%
my_object._Privateclass__private_data
# Out:
# 20
